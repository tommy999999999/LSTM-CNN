# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, Flatten, Input, Dropout
from keras.optimizers import Adam
from keras.metrics import RootMeanSquaredError
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt  # Import sqrt function

# Load the data
df = pd.read_csv('cardiovascular.csv')

# Convert 'Sold_date' to datetime format and set as index
df['Sold_date'] = pd.to_datetime(df['Sold_date'], format='%m/%d/%y')
df.set_index('Sold_date', inplace=True)

# Aggregate sales data on a weekly basis for each product
weekly_data = df.pivot_table(values='Sold_quantity', index='Sold_date', 
                             columns='Product_details', aggfunc='sum').resample('W').sum()

# Normalize the sales data
scaler = MinMaxScaler()
weekly_data_scaled = scaler.fit_transform(weekly_data)
weekly_data_scaled = pd.DataFrame(weekly_data_scaled, index=weekly_data.index, columns=weekly_data.columns)

# Prepare data for LSTM
def create_sequences(data, sequence_length):
    x = []
    y = []
    for i in range(len(data) - sequence_length):
        x.append(data.iloc[i:i + sequence_length].values)
        y.append(data.iloc[i + sequence_length].values)
    return np.array(x), np.array(y)

sequence_length = 2  # Number of weeks used to predict the next week
x_lstm, y_lstm = create_sequences(weekly_data_scaled, sequence_length)

print("x_lstm shape:", x_lstm.shape)
print("y_lstm shape:", y_lstm.shape)
# Out:
# x_lstm shape: (162, 2, 50)
# y_lstm shape: (162, 50)

# %%
# Define the LSTM model to extract features
lstm_model = Sequential([
    Input(shape=(sequence_length, len(weekly_data_scaled.columns))),
    LSTM(50, activation='tanh', recurrent_activation='sigmoid', return_sequences=False),
])

# Compile the LSTM model
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Fit the LSTM model
history = lstm_model.fit(x_lstm, y_lstm, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# Extract features using LSTM
features = lstm_model.predict(x_lstm)

# Print the features of the first three samples to see what they look like
print("Features of the first three samples:\n", features[:3])

# Enhanced CNN model with additional complexity and dropout for regularization
input_shape = (features.shape[1], features.shape[2]) if len(features.shape) == 3 else (features.shape[1], 1)
cnn_model_enhanced = Sequential([
    Input(shape=input_shape),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Dropout(0.2),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.2),
    Dense(len(weekly_data.columns))
])

cnn_model_enhanced.compile(optimizer=Adam(), loss='mean_squared_error', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Model summary
cnn_model_enhanced.summary()

# Fit the CNN model
history = cnn_model_enhanced.fit(features, y_lstm, epochs=100, batch_size=32, validation_split=0.2)

# Predictions made by the CNN model
scaled_predictions = cnn_model_enhanced.predict(features)

# Display RMSE
print("Root Mean Squared Error (RMSE):")
print(history.history['root_mean_squared_error'])

# Assuming `y_lstm` and `scaled_predictions` have the same second dimension (number of features or products)
if scaled_predictions.shape[1] == y_lstm.shape[1]:
    actual_predictions = scaler.inverse_transform(scaled_predictions)
    actual_targets = scaler.inverse_transform(y_lstm)
else:
    print("Error: Mismatch in dimensions between predictions and actuals.")

# Calculate RMSE in original units
rmse_original = sqrt(mean_squared_error(actual_targets, actual_predictions))
print("RMSE on original scale:", rmse_original)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0324 - val_loss: 0.0399
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0308 - val_loss: 0.0389
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0292 - val_loss: 0.0381
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0288 - val_loss: 0.0373
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0291 - val_loss: 0.0365
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0277 - val_loss: 0.0359
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0257 - val_loss: 0.0353
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0261 - val_loss: 0.0347
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0269 - val_loss: 0.0342
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0244 - val_loss: 0.0337
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0247 - val_loss: 0.0332
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0236 - val_loss: 0.0328
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
#    0.03838931 -0.00158264  0.02068359  0.0168172   0.05245175  0.09644978
#    0.07891694  0.05744389  0.04374765  0.05027921  0.00764499  0.02167879
#    0.04197171  0.01188627]
#  [ 0.16778244  0.04859408  0.14906761  0.01854124  0.0435891  -0.00598409
#    0.00054176  0.00728477 -0.01214392  0.00578024  0.03198407  0.07835826
#    0.02493018 -0.01764585  0.02265008  0.03654059  0.02706635  0.00859578
#   -0.02317134  0.06872467  0.09322292  0.02721857 -0.00158224  0.05244192
#    0.00568444  0.13903701 -0.02116066  0.12283575  0.01524152  0.06042478
#    0.00037191  0.05641403  0.01938255 -0.01312876  0.00943212 -0.00110146
#    0.00129078  0.01209346  0.00174691  0.02506446  0.0296187   0.08471242
#    0.07434218  0.07246947  0.00613341  0.03553579  0.00305192 -0.00661483
#    0.05288864 -0.00836672]
#  [ 0.25673532  0.02384541  0.29377723  0.00236634  0.08092063 -0.05118589
#   -0.00577756  0.01058084 -0.04469785  0.0025035   0.06246803  0.16914265
#    0.0168214   0.01519749 -0.00489524  0.02435615  0.00463192 -0.01823792
#   -0.01426924  0.0612791   0.10579304 -0.02515766 -0.00562441  0.05459822
#    0.01028977  0.17701162 -0.03673684  0.2205515  -0.00662456  0.08752587
#   -0.05960162  0.10811876  0.02890227  0.00397054 -0.01341745  0.00593277
#    0.02068746 -0.00678006 -0.00282209 -0.00807441  0.0409895   0.14288284
#    0.15020433  0.07904458  0.00529339  0.03990963  0.00681599 -0.02615911
#    0.08896164 -0.04039788]]
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 48, 128)        │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 24, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 22, 128)        │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 11, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1408)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 100)            │       140,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │         5,050 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 195,742 (764.62 KB)
#  Trainable params: 195,742 (764.62 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0297 - root_mean_squared_error: 0.1723 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1871
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0261 - root_mean_squared_error: 0.1615 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1835
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0246 - root_mean_squared_error: 0.1567 - val_loss: 0.0326 - val_root_mean_squared_error: 0.1806
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233 - root_mean_squared_error: 0.1526 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1790
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233 - root_mean_squared_error: 0.1526 - val_loss: 0.0314 - val_root_mean_squared_error: 0.1773
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0232 - root_mean_squared_error: 0.1524 - val_loss: 0.0311 - val_root_mean_squared_error: 0.1765
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0225 - root_mean_squared_error: 0.1500 - val_loss: 0.0306 - val_root_mean_squared_error: 0.1749
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0219 - root_mean_squared_error: 0.1479 - val_loss: 0.0302 - val_root_mean_squared_error: 0.1739
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0218 - root_mean_squared_error: 0.1476 - val_loss: 0.0297 - val_root_mean_squared_error: 0.1723
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0225 - root_mean_squared_error: 0.1500 - val_loss: 0.0300 - val_root_mean_squared_error: 0.1732
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.0305 - val_root_mean_squared_error: 0.1747
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0205 - root_mean_squared_error: 0.1433 - val_loss: 0.0300 - val_root_mean_squared_error: 0.1732
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0197 - root_mean_squared_error: 0.1402 - val_loss: 0.0298 - val_root_mean_squared_error: 0.1726
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0212 - root_mean_squared_error: 0.1454 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1728
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - root_mean_squared_error: 0.1466 - val_loss: 0.0302 - val_root_mean_squared_error: 0.1738
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0224 - root_mean_squared_error: 0.1494 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1735
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0219 - root_mean_squared_error: 0.1480 - val_loss: 0.0297 - val_root_mean_squared_error: 0.1724
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0208 - root_mean_squared_error: 0.1443 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1729
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0208 - root_mean_squared_error: 0.1442 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1734
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0200 - root_mean_squared_error: 0.1414 - val_loss: 0.0298 - val_root_mean_squared_error: 0.1727
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0204 - root_mean_squared_error: 0.1428 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1719
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0201 - root_mean_squared_error: 0.1418 - val_loss: 0.0294 - val_root_mean_squared_error: 0.1714
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0203 - root_mean_squared_error: 0.1426 - val_loss: 0.0297 - val_root_mean_squared_error: 0.1724
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425 - val_loss: 0.0298 - val_root_mean_squared_error: 0.1726
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0206 - root_mean_squared_error: 0.1434 - val_loss: 0.0294 - val_root_mean_squared_error: 0.1715
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0211 - root_mean_squared_error: 0.1451 - val_loss: 0.0293 - val_root_mean_squared_error: 0.1713
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1720
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0204 - root_mean_squared_error: 0.1428 - val_loss: 0.0295 - val_root_mean_squared_error: 0.1718
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0208 - root_mean_squared_error: 0.1439 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1708
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0194 - root_mean_squared_error: 0.1392 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1708
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1700
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0202 - root_mean_squared_error: 0.1422 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1695
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1703
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0193 - root_mean_squared_error: 0.1389 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1706
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0188 - root_mean_squared_error: 0.1372 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1703
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0184 - root_mean_squared_error: 0.1355 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1700
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1698
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0188 - root_mean_squared_error: 0.1369 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1707
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0188 - root_mean_squared_error: 0.1370 - val_loss: 0.0293 - val_root_mean_squared_error: 0.1711
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0193 - root_mean_squared_error: 0.1389 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1700
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1695
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - root_mean_squared_error: 0.1379 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1694
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0193 - root_mean_squared_error: 0.1389 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1696
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0181 - root_mean_squared_error: 0.1346 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1702
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0178 - root_mean_squared_error: 0.1332 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1708
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - root_mean_squared_error: 0.1379 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1697
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0187 - root_mean_squared_error: 0.1368 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1695
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0179 - root_mean_squared_error: 0.1337 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1697
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0175 - root_mean_squared_error: 0.1325 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1707
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0172 - root_mean_squared_error: 0.1311 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1703
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0193 - root_mean_squared_error: 0.1387 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1700
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1329 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1696
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0173 - root_mean_squared_error: 0.1315 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1697
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - root_mean_squared_error: 0.1375 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1697
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1692
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0175 - root_mean_squared_error: 0.1324 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1701
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1734
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0191 - root_mean_squared_error: 0.1380 - val_loss: 0.0293 - val_root_mean_squared_error: 0.1710
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - root_mean_squared_error: 0.1378 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1703
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1698
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0176 - root_mean_squared_error: 0.1328 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1702
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1330 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1694
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0179 - root_mean_squared_error: 0.1338 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1692
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1701
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0163 - root_mean_squared_error: 0.1275 - val_loss: 0.0293 - val_root_mean_squared_error: 0.1711
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0170 - root_mean_squared_error: 0.1304 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1701
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1697
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0170 - root_mean_squared_error: 0.1305 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1705
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0176 - root_mean_squared_error: 0.1327 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1702
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1697
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0168 - root_mean_squared_error: 0.1296 - val_loss: 0.0285 - val_root_mean_squared_error: 0.1687
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1694
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1702
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0169 - root_mean_squared_error: 0.1298 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1708
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0161 - root_mean_squared_error: 0.1269 - val_loss: 0.0294 - val_root_mean_squared_error: 0.1716
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0160 - root_mean_squared_error: 0.1266 - val_loss: 0.0295 - val_root_mean_squared_error: 0.1718
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - root_mean_squared_error: 0.1272 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1720
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0167 - root_mean_squared_error: 0.1291 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1729
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0170 - root_mean_squared_error: 0.1304 - val_loss: 0.0295 - val_root_mean_squared_error: 0.1717
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - root_mean_squared_error: 0.1285 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1709
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0161 - root_mean_squared_error: 0.1267 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1705
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1706
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0164 - root_mean_squared_error: 0.1279 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1709
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - root_mean_squared_error: 0.1271 - val_loss: 0.0297 - val_root_mean_squared_error: 0.