# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, Flatten, Input, Dropout
from keras.optimizers import Adam
from keras.metrics import RootMeanSquaredError
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt  # Import sqrt function

# Load the data
df = pd.read_csv('Vitamins.csv')

# Convert 'Sold_date' to datetime format and set as index
df['Sold_date'] = pd.to_datetime(df['Sold_date'], format='%m/%d/%y')
df.set_index('Sold_date', inplace=True)

# Aggregate sales data on a weekly basis for each product
weekly_data = df.pivot_table(values='Sold_quantity', index='Sold_date', 
                             columns='Product_details', aggfunc='sum').resample('W').sum()

# Normalize the sales data
scaler = MinMaxScaler()
weekly_data_scaled = scaler.fit_transform(weekly_data)
weekly_data_scaled = pd.DataFrame(weekly_data_scaled, index=weekly_data.index, columns=weekly_data.columns)

# Prepare data for LSTM
def create_sequences(data, sequence_length):
    x = []
    y = []
    for i in range(len(data) - sequence_length):
        x.append(data.iloc[i:i + sequence_length].values)
        y.append(data.iloc[i + sequence_length].values)
    return np.array(x), np.array(y)

sequence_length = 2  # Number of weeks used to predict the next week
x_lstm, y_lstm = create_sequences(weekly_data_scaled, sequence_length)

print("x_lstm shape:", x_lstm.shape)
print("y_lstm shape:", y_lstm.shape)
# Out:
# x_lstm shape: (162, 2, 196)
# y_lstm shape: (162, 196)

# %%
lstm_model = Sequential([
    Input(shape=(sequence_length, len(weekly_data_scaled.columns))),
    LSTM(196, activation='tanh', recurrent_activation='sigmoid', return_sequences=False),
])
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Fit the LSTM model
history = lstm_model.fit(x_lstm, y_lstm, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# Extract features using LSTM
features = lstm_model.predict(x_lstm)

# Define and compile the CNN model
input_shape = (features.shape[1], 1)
cnn_model_enhanced = Sequential([
    Input(shape=input_shape),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Dropout(0.2),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.2),
    Dense(len(weekly_data.columns))
])
cnn_model_enhanced.compile(optimizer=Adam(), loss='mean_squared_error', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Fit the CNN model
history_cnn = cnn_model_enhanced.fit(features, y_lstm, epochs=100, batch_size=32, validation_split=0.2)

# Predictions made by the CNN model
scaled_predictions = cnn_model_enhanced.predict(features)

# Inverse transform the scaled predictions to original scale
actual_predictions = scaler.inverse_transform(scaled_predictions)

# Create a DataFrame for the forecasted data
forecast_df = pd.DataFrame(actual_predictions, index=weekly_data.index[sequence_length:], columns=weekly_data.columns)

# Reindex the forecast DataFrame to ensure it includes the required date range
forecast_df = forecast_df.reindex(pd.date_range(start=weekly_data.index[sequence_length], end=weekly_data.index[-1], freq='W'))

# Display the forecast for the week of February 5 to 11, 2024
forecast_week = forecast_df.loc['2024-02-04']  # The week starting on February 4, 2024
sorted_forecast_week = forecast_week.sort_values(ascending=False)  # Sort values from highest to lowest

# Convert to DataFrame and save the sorted forecast to Excel
sorted_forecast_week_df = sorted_forecast_week.to_frame(name='Sold_quantity')
sorted_forecast_week_df.index.name = 'Product_details'
sorted_forecast_week_df.reset_index(inplace=True)
sorted_forecast_week_df.to_excel('vitamins_sorted_by_quantity.xlsx', index=False)

# Display RMSE
print("Root Mean Squared Error (RMSE):", history_cnn.history['root_mean_squared_error'])

# Calculate and print RMSE in original units
rmse_original = sqrt(mean_squared_error(y_lstm, actual_predictions))
print("RMSE on original scale:", rmse_original)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0389 - val_loss: 0.0476
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0345 - val_loss: 0.0452
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0322 - val_loss: 0.0434
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0301 - val_loss: 0.0422
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0280 - val_loss: 0.0413
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0275 - val_loss: 0.0409
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0259 - val_loss: 0.0407
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0248 - val_loss: 0.0407
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0244 - val_loss: 0.0406
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0247 - val_loss: 0.0405
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0237 - val_loss: 0.0404
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0231 - val_loss: 0.0403
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0232 - val_loss: 0.0403
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0229 - val_loss: 0.0403
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0222 - val_loss: 0.0403
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0219 - val_loss: 0.0403
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0216 - val_loss: 0.0404
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0213 - val_loss: 0.0404
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0213 - val_loss: 0.0404
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0203 - val_loss: 0.0404
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0198 - val_loss: 0.0405
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0199 - val_loss: 0.0405
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0193 - val_loss: 0.0406
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0193 - val_loss: 0.0407
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0189 - val_loss: 0.0409
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0185 - val_loss: 0.0409
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0179 - val_loss: 0.0409
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0181 - val_loss: 0.0410
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0177 - val_loss: 0.0411
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0177 - val_loss: 0.0412
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0169 - val_loss: 0.0414
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0168 - val_loss: 0.0417
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0166 - val_loss: 0.0419
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0163 - val_loss: 0.0420
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0162 - val_loss: 0.0422
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0155 - val_loss: 0.0423
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0154 - val_loss: 0.0425
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0157 - val_loss: 0.0425
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0155 - val_loss: 0.0426
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0151 - val_loss: 0.0427
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0147 - val_loss: 0.0429
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0146 - val_loss: 0.0430
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0141 - val_loss: 0.0431
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0139 - val_loss: 0.0432
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0138 - val_loss: 0.0432
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0140 - val_loss: 0.0433
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - val_loss: 0.0436
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - val_loss: 0.0439
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0129 - val_loss: 0.0441
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0127 - val_loss: 0.0442
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124 - val_loss: 0.0443
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124 - val_loss: 0.0445
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - val_loss: 0.0447
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0119 - val_loss: 0.0449
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0114 - val_loss: 0.0451
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0116 - val_loss: 0.0452
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0112 - val_loss: 0.0453
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0108 - val_loss: 0.0456
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0108 - val_loss: 0.0458
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0107 - val_loss: 0.0460
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0104 - val_loss: 0.0461
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0101 - val_loss: 0.0462
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0100 - val_loss: 0.0465
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0100 - val_loss: 0.0466
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0097 - val_loss: 0.0467
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0098 - val_loss: 0.0469
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094 - val_loss: 0.0471
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094 - val_loss: 0.0473
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - val_loss: 0.0475
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - val_loss: 0.0476
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0086 - val_loss: 0.0478
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0086 - val_loss: 0.0481
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084 - val_loss: 0.0483
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083 - val_loss: 0.0484
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0082 - val_loss: 0.0486
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0080 - val_loss: 0.0487
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078 - val_loss: 0.0489
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0080 - val_loss: 0.0491
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0076 - val_loss: 0.0492
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077 - val_loss: 0.0493
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - val_loss: 0.0495
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - val_loss: 0.0497
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070 - val_loss: 0.0500
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072 - val_loss: 0.0504
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0504
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0503
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0504
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0506
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - val_loss: 0.0507
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063 - val_loss: 0.0508
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - val_loss: 0.0508
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - val_loss: 0.0507
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063 - val_loss: 0.0509
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - val_loss: 0.0512
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - val_loss: 0.0513
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - val_loss: 0.0514
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055 - val_loss: 0.0515
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0054 - val_loss: 0.0516
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - val_loss: 0.0517
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0054 - val_loss: 0.0520
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0362 - root_mean_squared_error: 0.1901 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2126
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0329 - root_mean_squared_error: 0.1814 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2092
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0307 - root_mean_squared_error: 0.1752 - val_loss: 0.0418 - val_root_mean_squared_error: 0.2044
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0292 - root_mean_squared_error: 0.1709 - val_loss: 0.0416 - val_root_mean_squared_error: 0.2040
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0281 - root_mean_squared_error: 0.1676 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2021
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0282 - root_mean_squared_error: 0.1679 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0272 - root_mean_squared_error: 0.1650 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0273 - root_mean_squared_error: 0.1651 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2018
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0260 - root_mean_squared_error: 0.1612 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2009
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0258 - root_mean_squared_error: 0.1607 - val_loss: 0.0403 - val_root_mean_squared_error: 0.2007
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0260 - root_mean_squared_error: 0.1611 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2018
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0257 - root_mean_squared_error: 0.1603 - val_loss: 0.0402 - val_root_mean_squared_error: 0.2005
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0245 - root_mean_squared_error: 0.1566 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2011
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0253 - root_mean_squared_error: 0.1589 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2011
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0242 - root_mean_squared_error: 0.1557 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0247 - root_mean_squared_error: 0.1572 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0238 - root_mean_squared_error: 0.1541 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2014
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0237 - root_mean_squared_error: 0.1540 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2020
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0233 - root_mean_squared_error: 0.1526 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2020
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0233 - root_mean_squared_error: 0.1526 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2009
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0232 - root_mean_squared_error: 0.1522 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2012
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0229 - root_mean_squared_error: 0.1515 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2015
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0227 - root_mean_squared_error: 0.1506 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2014
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0229 - root_mean_squared_error: 0.1514 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2019
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0224 - root_mean_squared_error: 0.1498 - val_loss: 0.0402 - val_root_mean_squared_error: 0.2005
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0225 - root_mean_squared_error: 0.1501 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0219 - root_mean_squared_error: 0.1479 - val_loss: 0.0403 - val_root_mean_squared_error: 0.2009
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0218 - root_mean_squared_error: 0.1476 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0217 - root_mean_squared_error: 0.1472 - val_loss: 0.0403 - val_root_mean_squared_error: 0.2008
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0215 - root_mean_squared_error: 0.1465 - val_loss: 0.0403 - val_root_mean_squared_error: 0.2008
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0219 - root_mean_squared_error: 0.1480 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2011
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0216 - root_mean_squared_error: 0.1469 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0214 - root_mean_squared_error: 0.1462 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2017
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0214 - root_mean_squared_error: 0.1463 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0212 - root_mean_squared_error: 0.1457 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2011
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0210 - root_mean_squared_error: 0.1450 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2012
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0206 - root_mean_squared_error: 0.1435 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0205 - root_mean_squared_error: 0.1431 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2021
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0208 - root_mean_squared_error: 0.1443 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2012
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0197 - root_mean_squared_error: 0.1405 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0208 - root_mean_squared_error: 0.1443 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2018
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0203 - root_mean_squared_error: 0.1424 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2020
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0201 - root_mean_squared_error: 0.1419 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2012
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0198 - root_mean_squared_error: 0.1409 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2025
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2030
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0199 - root_mean_squared_error: 0.1412 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2027
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0200 - root_mean_squared_error: 0.1413 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2027
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0201 - root_mean_squared_error: 0.1417 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2019
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0197 - root_mean_squared_error: 0.1403 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2031
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0195 - root_mean_squared_error: 0.1398 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2024
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0191 - root_mean_squared_error: 0.1383 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2026
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0188 - root_mean_squared_error: 0.1370 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2030
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0185 - root_mean_squared_error: 0.1361 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2022
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0191 - root_mean_squared_error: 0.1383 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2028
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0183 - root_mean_squared_error: 0.1352 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2026
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2026
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0187 - root_mean_squared_error: 0.1366 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2029
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0183 - root_mean_squared_error: 0.1351 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2022
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2026
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0179 - root_mean_squared_error: 0.1339 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2025
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0185 - root_mean_squared_error: 0.1360 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2027
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0174 - root_mean_squared_error: 0.1320 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2031
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0179 - root_mean_squared_error: 0.1338 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2026
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2026
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2027
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2033
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0174 - root_mean_squared_error: 0.1321 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2031
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2030
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0170 - root_mean_squared_error: 0.1305 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2033
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2032
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0174 - root_mean_squared_error: 0.1318 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2030
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0178 - root_mean_squared_error: 0.1334 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2031
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0166 - root_mean_squared_error: 0.1287 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2029
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0163 - root_mean_squared_error: 0.1276 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2035
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0165 - root_mean_squared_error: 0.1284 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2033
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0162 - root_mean_squared_error: 0.1271 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2032
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0169 - root_mean_squared_error: 0.1301 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2032
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0161 - root_mean_squared_error: 0.1267 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2035
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0165 - root_mean_squared_error: 0.1284 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2038
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0165 - root_mean_squared_error: 0.1284 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2038
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0158 - root_mean_squared_error: 0.1255 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2037
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0157 - root_mean_squared_error: 0.1251 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2037
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0161 - root_mean_squared_error: 0.1268 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2037
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0161 - root_mean_squared_error: 0.1268 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2035
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0164 - root_mean_squared_error: 0.1282 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2034
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0157 - root_mean_squared_error: 0.1253 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2037
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0161 - root_mean_squared_error: 0.1267 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2034
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0162 - root_mean_squared_error: 0.1273 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2034
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0156 - root_mean_squared_error: 0.1247 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2035
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0161 - root_mean_squared_error: 0.1268 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2033
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0158 - root_mean_squared_error: 0.1256 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2038
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0158 - root_mean_squared_error: 0.1258 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2035
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2035
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0157 - root_mean_squared_error: 0.1255 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2036
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0153 - root_mean_squared_error: 0.1236 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2033
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0151 - root_mean_squared_error: 0.1228 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2036
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0157 - root_mean_squared_error: 0.1253 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2034
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0156 - root_mean_squared_error: 0.1247 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2027
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0152 - root_mean_squared_error: 0.1235 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2029
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Root Mean Squared Error (RMSE): [0.18859286606311798, 0.18071377277374268, 0.1752641648054123, 0.17108547687530518, 0.16844090819358826, 0.16600140929222107, 0.1644205003976822, 0.1634470820426941, 0.16191144287586212, 0.16108690202236176, 0.1609552949666977, 0.1593177765607834, 0.1583484560251236, 0.15725718438625336, 0.15636266767978668, 0.1552620530128479, 0.15470841526985168, 0.154597207903862, 0.15341195464134216, 0.1533687263727188, 0.15171237289905548, 0.15177881717681885, 0.15132176876068115, 0.15042833983898163, 0.15157286822795868, 0.1497633457183838, 0.14849941432476044, 0.1484786421060562, 0.1473539024591446, 0.1467071771621704, 0.1466687172651291, 0.14742065966129303, 0.1461682766675949, 0.14605198800563812, 0.14723023772239685, 0.14622248709201813, 0.14477290213108063, 0.1435277909040451, 0.14291340112686157, 0.14310486614704132, 0.14157195389270782, 0.14220023155212402, 0.14173263311386108, 0.1411387324333191, 0.14028742909431458, 0.14013752341270447, 0.1402631253004074, 0.14268694818019867, 0.1412087082862854, 0.13989557325839996, 0.13824404776096344, 0.138240784406662, 0.13769085705280304, 0.13783998787403107, 0.13778537511825562, 0.13737203180789948, 0.13580222427845, 0.13558250665664673, 0.1346835494041443, 0.13471868634223938, 0.13470907509326935, 0.13488595187664032, 0.13239112496376038, 0.13288986682891846, 0.1330668330192566, 0.1333780735731125, 0.13353848457336426, 0.13278858363628387, 0.13116663694381714, 0.13099102675914764, 0.12964294850826263, 0.13048000633716583, 0.13113227486610413, 0.12958924472332, 0.12800532579421997, 0.12889209389686584, 0.12765264511108398, 0.12946659326553345, 0.1268913596868515, 0.12779279053211212, 0.12864860892295837, 0.12668754160404205, 0.12618260085582733, 0.12797939777374268, 0.12635163962841034, 0.1280226707458496, 0.12652543187141418, 0.12636932730674744, 0.12642525136470795, 0.12449250370264053, 0.12715861201286316, 0.12562890350818634, 0.12632323801517487, 0.12527576088905334, 0.1261480748653412, 0.12325738370418549, 0.12452083081007004, 0.12491460889577866, 0.12511876225471497, 0.1239754930138588]
# RMSE on original scale: 10.156815862914721
