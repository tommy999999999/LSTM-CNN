# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, Flatten, Input, Dropout
from keras.optimizers import Adam
from keras.metrics import RootMeanSquaredError
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt  # Import sqrt function

# Load the data
df = pd.read_csv('mucolytics.csv')

# Convert 'Sold_date' to datetime format and set as index
df['Sold_date'] = pd.to_datetime(df['Sold_date'], format='%m/%d/%y')
df.set_index('Sold_date', inplace=True)

# Aggregate sales data on a weekly basis for each product
weekly_data = df.pivot_table(values='Sold_quantity', index='Sold_date', 
                             columns='Product_details', aggfunc='sum').resample('W').sum()

# Normalize the sales data
scaler = MinMaxScaler()
weekly_data_scaled = scaler.fit_transform(weekly_data)
weekly_data_scaled = pd.DataFrame(weekly_data_scaled, index=weekly_data.index, columns=weekly_data.columns)

# Prepare data for LSTM
def create_sequences(data, sequence_length):
    x = []
    y = []
    for i in range(len(data) - sequence_length):
        x.append(data.iloc[i:i + sequence_length].values)
        y.append(data.iloc[i + sequence_length].values)
    return np.array(x), np.array(y)

sequence_length = 2  # Number of weeks used to predict the next week
x_lstm, y_lstm = create_sequences(weekly_data_scaled, sequence_length)

print("x_lstm shape:", x_lstm.shape)
print("y_lstm shape:", y_lstm.shape)
# Out:
# x_lstm shape: (162, 2, 49)
# y_lstm shape: (162, 49)

# %%
lstm_model = Sequential([
    Input(shape=(sequence_length, len(weekly_data_scaled.columns))),
    LSTM(49, activation='tanh', recurrent_activation='sigmoid', return_sequences=False),
])
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Fit the LSTM model
history = lstm_model.fit(x_lstm, y_lstm, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# Extract features using LSTM
features = lstm_model.predict(x_lstm)

# Define and compile the CNN model
input_shape = (features.shape[1], 1)
cnn_model_enhanced = Sequential([
    Input(shape=input_shape),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Dropout(0.2),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.2),
    Dense(len(weekly_data.columns))
])
cnn_model_enhanced.compile(optimizer=Adam(), loss='mean_squared_error', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Fit the CNN model
history_cnn = cnn_model_enhanced.fit(features, y_lstm, epochs=100, batch_size=32, validation_split=0.2)

# Predictions made by the CNN model
scaled_predictions = cnn_model_enhanced.predict(features)

# Inverse transform the scaled predictions to original scale
actual_predictions = scaler.inverse_transform(scaled_predictions)

# Create a DataFrame for the forecasted data
forecast_df = pd.DataFrame(actual_predictions, index=weekly_data.index[sequence_length:], columns=weekly_data.columns)

# Reindex the forecast DataFrame to ensure it includes the required date range
forecast_df = forecast_df.reindex(pd.date_range(start=weekly_data.index[sequence_length], end=weekly_data.index[-1], freq='W'))

# Display the forecast for the week of February 5 to 11, 2024
forecast_week = forecast_df.loc['2024-02-04']  # The week starting on February 4, 2024
sorted_forecast_week = forecast_week.sort_values(ascending=False)  # Sort values from highest to lowest

# Convert to DataFrame and save the sorted forecast to Excel
sorted_forecast_week_df = sorted_forecast_week.to_frame(name='Sold_quantity')
sorted_forecast_week_df.index.name = 'Product_details'
sorted_forecast_week_df.reset_index(inplace=True)
sorted_forecast_week_df.to_excel('mucolytics1_sorted_by_quantity.xlsx', index=False)

# Display RMSE
print("Root Mean Squared Error (RMSE):", history_cnn.history['root_mean_squared_error'])

# Calculate and print RMSE in original units
rmse_original = sqrt(mean_squared_error(y_lstm, actual_predictions))
print("RMSE on original scale:", rmse_original)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0392 - val_loss: 0.0609
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0373 - val_loss: 0.0581
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0342 - val_loss: 0.0557
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0338 - val_loss: 0.0536
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0349 - val_loss: 0.0519
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0318 - val_loss: 0.0504
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0316 - val_loss: 0.0492
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0299 - val_loss: 0.0481
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0267 - root_mean_squared_error: 0.1634 - val_loss: 0.0442 - val_root_mean_squared_error: 0.2101
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0262 - root_mean_squared_error: 0.1617 - val_loss: 0.0444 - val_root_mean_squared_error: 0.2108
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0257 - root_mean_squared_error: 0.1603 - val_loss: 0.0446 - val_root_mean_squared_error: 0.2111
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0268 - root_mean_squared_error: 0.1637 - val_loss: 0.0446 - val_root_mean_squared_error: 0.2112
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0256 - root_mean_squared_error: 0.1601 - val_loss: 0.0455 - val_root_mean_squared_error: 0.2133
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0270 - root_mean_squared_error: 0.1642 - val_loss: 0.0444 - val_root_mean_squared_error: 0.2108
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0262 - root_mean_squared_error: 0.1619 - val_loss: 0.0445 - val_root_mean_squared_error: 0.2110
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0247 - root_mean_squared_error: 0.1571 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2122
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0266 - root_mean_squared_error: 0.1631 - val_loss: 0.0441 - val_root_mean_squared_error: 0.2101
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0257 - root_mean_squared_error: 0.1602 - val_loss: 0.0435 - val_root_mean_squared_error: 0.2085
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0237 - root_mean_squared_error: 0.1539 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2105
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0247 - root_mean_squared_error: 0.1572 - val_loss: 0.0446 - val_root_mean_squared_error: 0.2113
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0249 - root_mean_squared_error: 0.1579 - val_loss: 0.0446 - val_root_mean_squared_error: 0.2112
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0255 - root_mean_squared_error: 0.1596 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2105
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0248 - root_mean_squared_error: 0.1575 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2106
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233 - root_mean_squared_error: 0.1528 - val_loss: 0.0441 - val_root_mean_squared_error: 0.2100
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0228 - root_mean_squared_error: 0.1509 - val_loss: 0.0436 - val_root_mean_squared_error: 0.2087
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0230 - root_mean_squared_error: 0.1518 - val_loss: 0.0432 - val_root_mean_squared_error: 0.2080
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0235 - root_mean_squared_error: 0.1532 - val_loss: 0.0429 - val_root_mean_squared_error: 0.2072
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0241 - root_mean_squared_error: 0.1554 - val_loss: 0.0435 - val_root_mean_squared_error: 0.2086
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0228 - root_mean_squared_error: 0.1508 - val_loss: 0.0437 - val_root_mean_squared_error: 0.2090
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - val_loss: 0.0433 - val_root_mean_squared_error: 0.2081
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0236 - root_mean_squared_error: 0.1537 - val_loss: 0.0439 - val_root_mean_squared_error: 0.2095
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233 - root_mean_squared_error: 0.1526 - val_loss: 0.0448 - val_root_mean_squared_error: 0.2117
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0227 - root_mean_squared_error: 0.1508 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2114
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511 - val_loss: 0.0441 - val_root_mean_squared_error: 0.2100
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0226 - root_mean_squared_error: 0.1503 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2093
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0225 - root_mean_squared_error: 0.1499 - val_loss: 0.0436 - val_root_mean_squared_error: 0.2089
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0225 - root_mean_squared_error: 0.1500 - val_loss: 0.0436 - val_root_mean_squared_error: 0.2089
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0221 - root_mean_squared_error: 0.1487 - val_loss: 0.0470 - val_root_mean_squared_error: 0.2168
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0239 - root_mean_squared_error: 0.1546 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2130
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0237 - root_mean_squared_error: 0.1539 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2114
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233 - root_mean_squared_error: 0.1527 - val_loss: 0.0449 - val_root_mean_squared_error: 0.2119
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0227 - root_mean_squared_error: 0.1507 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2126
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0220 - root_mean_squared_error: 0.1481 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2130
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0216 - root_mean_squared_error: 0.1468 - val_loss: 0.0453 - val_root_mean_squared_error: 0.2128
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0225 - root_mean_squared_error: 0.1500 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2125
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0212 - root_mean_squared_error: 0.1457 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2126
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0202 - root_mean_squared_error: 0.1420 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2121
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0218 - root_mean_squared_error: 0.1476 - val_loss: 0.0453 - val_root_mean_squared_error: 0.2128
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0219 - root_mean_squared_error: 0.1481 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2131
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0220 - root_mean_squared_error: 0.1484 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2130
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0207 - root_mean_squared_error: 0.1437 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2131
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - root_mean_squared_error: 0.1465 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2121
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0225 - root_mean_squared_error: 0.1500 - val_loss: 0.0449 - val_root_mean_squared_error: 0.2118
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0209 - root_mean_squared_error: 0.1447 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2120
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0218 - root_mean_squared_error: 0.1475 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2125
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0213 - root_mean_squared_error: 0.1460 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2122
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0208 - root_mean_squared_error: 0.1442 - val_loss: 0.0453 - val_root_mean_squared_error: 0.2129
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0206 - root_mean_squared_error: 0.1436 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2127
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0210 - root_mean_squared_error: 0.1449 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2124
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0213 - root_mean_squared_error: 0.1459 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2131
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0202 - root_mean_squared_error: 0.1423 - val_loss: 0.0458 - val_root_mean_squared_error: 0.2140
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0211 - root_mean_squared_error: 0.1451 - val_loss: 0.0461 - val_root_mean_squared_error: 0.2146
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0201 - root_mean_squared_error: 0.1418 - val_loss: 0.0458 - val_root_mean_squared_error: 0.2140
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0204 - root_mean_squared_error: 0.1427 - val_loss: 0.0460 - val_root_mean_squared_error: 0.2146
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0206 - root_mean_squared_error: 0.1435 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2130
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0208 - root_mean_squared_error: 0.1441 - val_loss: 0.0453 - val_root_mean_squared_error: 0.2129
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0199 - root_mean_squared_error: 0.1409 - val_loss: 0.0456 - val_root_mean_squared_error: 0.2136
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0193 - root_mean_squared_error: 0.1391 - val_loss: 0.0461 - val_root_mean_squared_error: 0.2147
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0207 - root_mean_squared_error: 0.1437 - val_loss: 0.0462 - val_root_mean_squared_error: 0.2150
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0200 - root_mean_squared_error: 0.1413 - val_loss: 0.0463 - val_root_mean_squared_error: 0.2151
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0199 - root_mean_squared_error: 0.1410 - val_loss: 0.0463 - val_root_mean_squared_error: 0.2152
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0195 - root_mean_squared_error: 0.1398 - val_loss: 0.0464 - val_root_mean_squared_error: 0.2154
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359 - val_loss: 0.0464 - val_root_mean_squared_error: 0.2153
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0186 - root_mean_squared_error: 0.1362 - val_loss: 0.0464 - val_root_mean_squared_error: 0.2155
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181 - root_mean_squared_error: 0.1345 - val_loss: 0.0469 - val_root_mean_squared_error: 0.2165
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0189 - root_mean_squared_error: 0.1375 - val_loss: 0.0462 - val_root_mean_squared_error: 0.2151
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0188 - root_mean_squared_error: 0.1373 - val_loss: 0.0459 - val_root_mean_squared_error: 0.2142
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0194 - root_mean_squared_error: 0.1391 - val_loss: 0.0457 - val_root_mean_squared_error: 0.2138
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0200 - root_mean_squared_error: 0.1413 - val_loss: 0.0468 - val_root_mean_squared_error: 0.2164
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0189 - root_mean_squared_error: 0.1374 - val_loss: 0.0472 - val_root_mean_squared_error: 0.2173
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0182 - root_mean_squared_error: 0.1349 - val_loss: 0.0470 - val_root_mean_squared_error: 0.2168
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0182 - root_mean_squared_error: 0.1348 - val_loss: 0.0466 - val_root_mean_squared_error: 0.2158
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - root_mean_squared_error: 0.1379 - val_loss: 0.0467 - val_root_mean_squared_error: 0.2160
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0191 - root_mean_squared_error: 0.1384 - val_loss: 0.0478 - val_root_mean_squared_error: 0.2185
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0186 - root_mean_squared_error: 0.1363 - val_loss: 0.0483 - val_root_mean_squared_error: 0.2198
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323 - val_loss: 0.0478 - val_root_mean_squared_error: 0.2187
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181 - root_mean_squared_error: 0.1344 - val_loss: 0.0470 - val_root_mean_squared_error: 0.2167
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0