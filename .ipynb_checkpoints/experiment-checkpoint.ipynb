# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, Flatten, Input, Dropout
from keras.optimizers import Adam
from keras.metrics import RootMeanSquaredError
import tensorflow as tf
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('food_supplements.csv')

# Convert 'Sold_date' to datetime format and set as index
df['Sold_date'] = pd.to_datetime(df['Sold_date'], format='%m/%d/%y')
df.set_index('Sold_date', inplace=True)

# Aggregate sales data on a weekly basis for each product
weekly_data = df.pivot_table(values='Sold_quantity', index='Sold_date', 
                             columns='Product_details', aggfunc='sum').resample('W').sum()
# Normalize the sales data
scaler = MinMaxScaler()
weekly_data_scaled = scaler.fit_transform(weekly_data)
weekly_data_scaled = pd.DataFrame(weekly_data_scaled, index=weekly_data.index, columns=weekly_data.columns)

# Prepare data for LSTM
def create_sequences(data, sequence_length):
    x = []
    y = []
    for i in range(len(data) - sequence_length):
        x.append(data.iloc[i:i + sequence_length].values)
        y.append(data.iloc[i + sequence_length].values)
    return np.array(x), np.array(y)


sequence_length = 2  # Number of weeks used to predict the next week
x_lstm, y_lstm = create_sequences(weekly_data_scaled, sequence_length)


# Define the LSTM model to extract features
lstm_model = Sequential([
    Input(shape=(sequence_length, len(weekly_data_scaled.columns))),
    LSTM(92, activation='tanh', recurrent_activation='sigmoid', return_sequences=False),
])

# Compile the LSTM model
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Fit the LSTM model
history = lstm_model.fit(x_lstm, y_lstm, epochs=100, batch_size=32, validation_split=0.2, verbose=1)


# Extract features using LSTM
features = lstm_model.predict(x_lstm)

# Enhanced CNN model with additional complexity and dropout for regularization
cnn_model_enhanced = Sequential([
    Input(shape=input_shape),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Dropout(0.2),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.2),
    Dense(len(weekly_data.columns))
])

# Compile the CNN model
cnn_model_enhanced.compile(optimizer=Adam(), loss='mean_squared_error', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Model summary
cnn_model_enhanced.summary()

# Fit the CNN model
history = cnn_model_enhanced.fit(features, y_lstm, epochs=100, batch_size=32, validation_split=0.2)

# Display RMSE
print("Root Mean Squared Error (RMSE):")
print(history.history['root_mean_squared_error'])
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0473 - val_loss: 0.0660
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0451 - val_loss: 0.0605
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0402 - val_loss: 0.0562
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0357 - val_loss: 0.0526
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0339 - val_loss: 0.0494
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0333 - val_loss: 0.0471
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0295 - val_loss: 0.0453
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0284 - val_loss: 0.0440
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0279 - val_loss: 0.0431
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0272 - val_loss: 0.0426
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0265 - val_loss: 0.0420
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0251 - val_loss: 0.0416
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0242 - val_loss: 0.0414
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0242 - val_loss: 0.0413
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0238 - val_loss: 0.0413
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0228 - val_loss: 0.0413
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0237 - val_loss: 0.0412
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0224 - val_loss: 0.0412
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0229 - val_loss: 0.0411
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0222 - val_loss: 0.0411
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0219 - val_loss: 0.0410
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0221 - val_loss: 0.0410
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0226 - val_loss: 0.0408
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0218 - val_loss: 0.0409
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211 - val_loss: 0.0409
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0213 - val_loss: 0.0408
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - val_loss: 0.0407
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - val_loss: 0.0405
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - val_loss: 0.0404
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - val_loss: 0.0403
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - val_loss: 0.0400
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0203 - val_loss: 0.0400
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - val_loss: 0.0399
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - val_loss: 0.0397
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - val_loss: 0.0395
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - val_loss: 0.0394
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197 - val_loss: 0.0391
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - val_loss: 0.0392
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0190 - val_loss: 0.0393
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0194 - val_loss: 0.0394
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0189 - val_loss: 0.0394
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0191 - val_loss: 0.0395
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0186 - val_loss: 0.0395
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - val_loss: 0.0395
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - val_loss: 0.0395
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184 - val_loss: 0.0395
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - val_loss: 0.0397
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - val_loss: 0.0399
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - val_loss: 0.
# %%
# Assuming 'history.history['root_mean_squared_error']' is your list of RMSE values
rmse_values = history.history['root_mean_squared_error']
final_rmse = rmse_values[-1]  # Access the last element in the list
print("Final RMSE:", final_rmse)
# Out:
# Final RMSE: 0.08264373987913132

# %%
# Predict using the trained CNN model
predicted_values = cnn_model.predict(features)

# Inverse transform the predicted values and the actual values
predicted_values = scaler.inverse_transform(predicted_values)
y_lstm_original = scaler.inverse_transform(y_lstm)

# Calculate RMSE in original units
mse = np.mean((predicted_values - y_lstm_original)**2)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE) in original units:", rmse)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Root Mean Squared Error (RMSE) in original units: 11.263313211097236

# %%
# Assuming 'cnn_model' is your compiled and trained CNN model
# and it contains at least one Conv1D layer at index 0 (as per your definition)

# Retrieve weights and biases from the first Conv1D layer
weights, biases = cnn_model.layers[0].get_weights()

# The 'weights' variable now contains all the kernels of the first Conv1D layer
# Each kernel has a shape of (kernel_size, num_input_channels, num_filters)
# Since you are using Conv1D, the number of input channels is usually the same as the feature dimension of your input

# Extract the first kernel
first_kernel = weights[:, :, 0]  # This gets the entire first filter across all input channels

# Print the first kernel
print("First Kernel Weights:\n", first_kernel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 # Assuming 'cnn_model' is your compiled and trained CNN model
#       2 # and it contains at least one Conv1D layer at index 0 (as per your definition)
#       3
#       4 # Retrieve weights and biases from the first Conv1D layer
# ----> 5 weights, biases = cnn_model.layers[0].get_weights()
#       7 # The 'weights' variable now contains all the kernels of the first Conv1D layer
#       8 # Each kernel has a shape of (kernel_size, num_input_channels, num_filters)
#       9 # Since you are using Conv1D, the number of input channels is usually the same as the feature dimension of your input
#      10
#      11 # Extract the first kernel
#      12 first_kernel = weights[:, :, 0]  # This gets the entire first filter across all input channels
#
# NameError: name 'cnn_model' is not defined

# %%
# Assuming 'cnn_model_enhanced' is your defined and compiled model
# Ensure the model is correctly compiled (and trained if you are looking at trained weights)

# Accessing weights from the first Conv1D layer of 'cnn_model_enhanced'
weights, biases = cnn_model_enhanced.layers[1].get_weights()  # Index might need to be adjusted based on actual model definition

# Extract the first kernel
# Adjust the indexing based on the actual dimensions of the weights
first_kernel = weights[:, :, 0]

# Print the first kernel
print("First Kernel Weights:\n", first_kernel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 # Assuming 'cnn_model_enhanced' is your defined and compiled model
#       2 # Ensure the model is correctly compiled (and trained if you are looking at trained weights)
#       3
#       4 # Accessing weights from the first Conv1D layer of 'cnn_model_enhanced'
# ----> 5 weights, biases = cnn_model_enhanced.layers[1].get_weights()  # Index might need to be adjusted based on actual model definition
#       7 # Extract the first kernel
#       8 # Adjust the indexing based on the actual dimensions of the weights
#       9 first_kernel = weights[:, :, 0]
#
# NameError: name 'cnn_model_enhanced' is not defined
