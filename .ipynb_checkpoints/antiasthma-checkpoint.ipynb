# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, Flatten, Input, Dropout
from keras.optimizers import Adam
from keras.metrics import RootMeanSquaredError
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt  # Import sqrt function

# Load the data
df = pd.read_csv('antiasthma.csv')

# Convert 'Sold_date' to datetime format and set as index
df['Sold_date'] = pd.to_datetime(df['Sold_date'], format='%m/%d/%y')
df.set_index('Sold_date', inplace=True)

# Aggregate sales data on a weekly basis for each product
weekly_data = df.pivot_table(values='Sold_quantity', index='Sold_date', 
                             columns='Product_details', aggfunc='sum').resample('W').sum()

# Normalize the sales data
scaler = MinMaxScaler()
weekly_data_scaled = scaler.fit_transform(weekly_data)
weekly_data_scaled = pd.DataFrame(weekly_data_scaled, index=weekly_data.index, columns=weekly_data.columns)

# Prepare data for LSTM
def create_sequences(data, sequence_length):
    x = []
    y = []
    for i in range(len(data) - sequence_length):
        x.append(data.iloc[i:i + sequence_length].values)
        y.append(data.iloc[i + sequence_length].values)
    return np.array(x), np.array(y)

sequence_length = 2  # Number of weeks used to predict the next week
x_lstm, y_lstm = create_sequences(weekly_data_scaled, sequence_length)

print("x_lstm shape:", x_lstm.shape)
print("y_lstm shape:", y_lstm.shape)
# Out:
# x_lstm shape: (161, 2, 45)
# y_lstm shape: (161, 45)

# %%
# Define the LSTM model to extract features
lstm_model = Sequential([
    Input(shape=(sequence_length, len(weekly_data_scaled.columns))),
    LSTM(45, activation='tanh', recurrent_activation='sigmoid', return_sequences=False),
])

# Compile the LSTM model
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Fit the LSTM model
history = lstm_model.fit(x_lstm, y_lstm, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# Extract features using LSTM
features = lstm_model.predict(x_lstm)

# Print the features of the first three samples to see what they look like
print("Features of the first three samples:\n", features[:3])

# Enhanced CNN model with additional complexity and dropout for regularization
input_shape = (features.shape[1], features.shape[2]) if len(features.shape) == 3 else (features.shape[1], 1)
cnn_model_enhanced = Sequential([
    Input(shape=input_shape),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Dropout(0.2),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.2),
    Dense(len(weekly_data.columns))
])

cnn_model_enhanced.compile(optimizer=Adam(), loss='mean_squared_error', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Model summary
cnn_model_enhanced.summary()

# Fit the CNN model
history = cnn_model_enhanced.fit(features, y_lstm, epochs=100, batch_size=32, validation_split=0.2)

# Predictions made by the CNN model
scaled_predictions = cnn_model_enhanced.predict(features)

# Display RMSE
print("Root Mean Squared Error (RMSE):")
print(history.history['root_mean_squared_error'])

# Assuming `y_lstm` and `scaled_predictions` have the same second dimension (number of features or products)
if scaled_predictions.shape[1] == y_lstm.shape[1]:
    actual_predictions = scaler.inverse_transform(scaled_predictions)
    actual_targets = scaler.inverse_transform(y_lstm)
else:
    print("Error: Mismatch in dimensions between predictions and actuals.")

# Calculate RMSE in original units
rmse_original = sqrt(mean_squared_error(actual_targets, actual_predictions))
print("RMSE on original scale:", rmse_original)
forecast_df.to_excel('antiasthma_results.xlsx', index=False)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0378 - val_loss: 0.0576
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0389 - val_loss: 0.0559
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0346 - val_loss: 0.0544
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0351 - val_loss: 0.0531
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0339 - val_loss: 0.0520
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0324 - val_loss: 0.0509
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0319 - val_loss: 0.0500
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0314 - val_loss: 0.0491
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0303 - val_loss: 0.0483
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0288 - val_loss: 0.0476
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0291 - val_loss: 0.0470
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0270 - val_loss: 0.0464
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0285 - val_loss: 0.0459
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0265 - val_loss: 0.0455
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0264 - val_loss: 0.0451
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0254 - val_loss: 0.0447
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0261 - val_loss: 0.0444
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0244 
- val_loss: 0.0409 - val_root_mean_squared_error: 0.2022
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0195 - root_mean_squared_error: 0.1395 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2019
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0200 - root_mean_squared_error: 0.1413 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2031
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0198 - root_mean_squared_error: 0.1408 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2031
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0201 - root_mean_squared_error: 0.1416 - val_loss: 0.0402 - val_root_mean_squared_error: 0.2006
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0197 - root_mean_squared_error: 0.1405 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2026
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0201 - root_mean_squared_error: 0.1417 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2029
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0195 - root_mean_squared_error: 0.1395 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2012
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0191 - root_mean_squared_error: 0.1381 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0184 - root_mean_squared_error: 0.1356 - val_loss: 0.0402 - val_root_mean_squared_error: 0.2006
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0185 - root_mean_squared_error: 0.1361 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2012
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0196 - root_mean_squared_error: 0.1399 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2015
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0184 - root_mean_squared_error: 0.1358 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2024
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0193 - root_mean_squared_error: 0.1387 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2018
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0182 - root_mean_squared_error: 0.1349 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2015
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2031
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0175 - root_mean_squared_error: 0.1324 - val_loss: 0.0401 - val_root_mean_squared_error: 0.2003
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0176 - root_mean_squared_error: 0.1328 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2027
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2032
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0169 - root_mean_squared_error: 0.1299 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0174 - root_mean_squared_error: 0.1317 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2023
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0161 - root_mean_squared_error: 0.1268 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2016
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - root_mean_squared_error: 0.1272 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2018
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2024
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0172 - root_mean_squared_error: 0.1311 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2027
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0164 - root_mean_squared_error: 0.1281 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2034
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0160 - root_mean_squared_error: 0.1266 - val_loss: 0.0416 - val_root_mean_squared_error: 0.2040
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0163 - root_mean_squared_error: 0.1277 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2030
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2021
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0158 - root_mean_squared_error: 0.1255 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2037
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0155 - root_mean_squared_error: 0.1243 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2038
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.0421 - val_root_mean_squared_error: 0.2051
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0151 - root_mean_squared_error: 0.1227 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2031
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0159 - root_mean_squared_error: 0.1259 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2030
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0151 - root_mean_squared_error: 0.1227 - val_loss: 0.0418 - val_root_mean_squared_error: 0.2046
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.0419 - val_root_mean_squared_error: 0.2047
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226 - val_loss: 0.0427 - val_root_mean_squared_error: 0.2066
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0151 - root_mean_squared_error: 0.1228 - val_loss: 0.0425 - val_root_mean_squared_error: 0.2061
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0146 - root_mean_squared_error: 0.1207 - val_loss: 0.0421 - val_root_mean_squared_error: 0.2051
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0148 - root_mean_squared_error: 0.1216 - val_loss: 0.0426 - val_root_mean_squared_error: 0.2063
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0139 - root_mean_squared_error: 0.1177 - val_loss: 0.0426 - val_root_mean_squared_error: 0.2065
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0143 - root_mean_squared_error: 0.1196 - val_loss: 0.0432 - val_root_mean_squared_error: 0.2079
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226 - val_loss: 0.0426 - val_root_mean_squared_error: 0.2063
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0147 - root_mean_squared_error: 0.1213 - val_loss: 0.0420 - val_root_mean_squared_error: 0.2050
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0422 - val_root_mean_squared_error: 0.2055
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187 - val_loss: 0.0432 - val_root_mean_squared_error: 0.2079
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.1204 - val_loss: 0.0435 - val_root_mean_squared_error: 0.2086
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0148 - root_mean_squared_error: 0.1218 - val_loss: 0.0433 - val_root_mean_squared_error: 0.2082
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0428 - val_root_mean_squared_error: 0.2068
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0138 - root_mean_squared_error: 0.1172 - val_loss: 0.0433 - val_root_mean_squared_error: 0.2081
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0138 - root_mean_squared_error: 0.1174 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2084
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.0433 - val_root_mean_squared_error: 0.2081
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - root_mean_squared_error: 0.1160 - val_loss: 0.0436 - val_root_mean_squared_error: 0.2088
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.0433 - val_root_mean_squared_error: 0.2081
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - root_mean_squared_error: 0.1172 - val_loss: 0.0436 - val_root_mean_squared_error: 0.2088
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0136 - root_mean_squared_error: 0.1167 - val_loss: 0.0436 - val_root_mean_squared_error: 0.2088
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0133 - root_mean_squared_error: 0.1152 - val_loss: 0.0437 - val_root_mean_squared_error: 0.2090
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - root_mean_squared_error: 0.1143 - val_loss: 0.0439 - val_root_mean_squared_error: 0.2094
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0130 