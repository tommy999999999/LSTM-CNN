# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, Flatten, Input, Dropout
from keras.optimizers import Adam
from keras.metrics import RootMeanSquaredError
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt  # Import sqrt function

# Load the data
df = pd.read_csv('antipyretic.csv')

# Convert 'Sold_date' to datetime format and set as index
df['Sold_date'] = pd.to_datetime(df['Sold_date'], format='%m/%d/%y')
df.set_index('Sold_date', inplace=True)

# Aggregate sales data on a weekly basis for each product
weekly_data = df.pivot_table(values='Sold_quantity', index='Sold_date', 
                             columns='Product_details', aggfunc='sum').resample('W').sum()

# Normalize the sales data
scaler = MinMaxScaler()
weekly_data_scaled = scaler.fit_transform(weekly_data)
weekly_data_scaled = pd.DataFrame(weekly_data_scaled, index=weekly_data.index, columns=weekly_data.columns)

# Prepare data for LSTM
def create_sequences(data, sequence_length):
    x = []
    y = []
    for i in range(len(data) - sequence_length):
        x.append(data.iloc[i:i + sequence_length].values)
        y.append(data.iloc[i + sequence_length].values)
    return np.array(x), np.array(y)

sequence_length = 2  # Number of weeks used to predict the next week
x_lstm, y_lstm = create_sequences(weekly_data_scaled, sequence_length)

print("x_lstm shape:", x_lstm.shape)
print("y_lstm shape:", y_lstm.shape)
# Out:
# x_lstm shape: (162, 2, 38)
# y_lstm shape: (162, 38)

# %%
# Define the LSTM model to extract features
lstm_model = Sequential([
    Input(shape=(sequence_length, len(weekly_data_scaled.columns))),
    LSTM(38, activation='tanh', recurrent_activation='sigmoid', return_sequences=False),
])

# Compile the LSTM model
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Fit the LSTM model
history = lstm_model.fit(x_lstm, y_lstm, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# Extract features using LSTM
features = lstm_model.predict(x_lstm)

# Print the features of the first three samples to see what they look like
print("Features of the first three samples:\n", features[:3])

# Enhanced CNN model with additional complexity and dropout for regularization
input_shape = (features.shape[1], features.shape[2]) if len(features.shape) == 3 else (features.shape[1], 1)
cnn_model_enhanced = Sequential([
    Input(shape=input_shape),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Dropout(0.2),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.2),
    Dense(len(weekly_data.columns))
])

cnn_model_enhanced.compile(optimizer=Adam(), loss='mean_squared_error', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Model summary
cnn_model_enhanced.summary()

# Fit the CNN model
history = cnn_model_enhanced.fit(features, y_lstm, epochs=100, batch_size=32, validation_split=0.2)

# Predictions made by the CNN model
scaled_predictions = cnn_model_enhanced.predict(features)

# Display RMSE
print("Root Mean Squared Error (RMSE):")
print(history.history['root_mean_squared_error'])

# Assuming `y_lstm` and `scaled_predictions` have the same second dimension (number of features or products)
if scaled_predictions.shape[1] == y_lstm.shape[1]:
    actual_predictions = scaler.inverse_transform(scaled_predictions)
    actual_targets = scaler.inverse_transform(y_lstm)
else:
    print("Error: Mismatch in dimensions between predictions and actuals.")

# Calculate RMSE in original units
rmse_original = sqrt(mean_squared_error(actual_targets, actual_predictions))
print("RMSE on original scale:", rmse_original)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0547 - val_loss: 0.0645
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0536 - val_loss: 0.0614
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0485 - val_loss: 0.0587
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0461 - val_loss: 0.0563
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0447 - val_loss: 0.0543
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0429 - val_loss: 0.0524
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0421 - val_loss: 0.0508
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0379 - val_loss: 0.0493
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0373 - val_loss: 0.0480
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0355 - val_loss: 0.0467
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0363 - val_loss: 0.0456
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0347 - val_loss: 0.0446
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0324 - val_loss: 0.0435
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0326 - val_loss: 0.0425
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0315 - val_loss: 0.0418
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0282 - val_loss: 0.0412
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0312 - val_loss: 0.0408
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0273 - val_loss: 0.0406
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0278 - val_loss: 0.0404
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0283 - val_loss: 0.0404
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0276 - val_loss: 0.0404
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0263 - val_loss: 0.0404
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0270 - val_loss: 0.0404
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0277 - val_loss: 0.0403
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0275 - val_loss: 0.0400
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0262 - val_loss: 0.0397
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0256 - val_loss: 0.0396
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0261 - val_loss: 0.0394
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0256 - val_loss: 0.0392
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0262 - val_loss: 0.0390
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0266 - val_loss: 0.0389
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0249 - val_loss: 0.0388
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0257 - val_loss: 0.0387
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0261 - val_loss: 0.0387
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0253 - val_loss: 0.0387
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0255 - val_loss: 0.0386
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0266 - val_loss: 0.0386
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0256 - val_loss: 0.0385
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0248 - val_loss: 0.0383
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0256 - val_loss: 0.0380
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0247 - val_loss: 0.0377
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0255 - val_loss: 0.0376
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0255 - val_loss: 0.0376
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0242 - val_loss: 0.0377
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0245 - val_loss: 0.0378
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0250 - val_loss: 0.0379
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0244 - val_loss: 0.0379
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0251 - val_loss: 0.0379
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0247 - val_loss: 0.0380
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0243 - val_loss: 0.0379
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0241 - val_loss: 0.0379
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0246 - val_loss: 0.0379
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0239 - val_loss: 0.0379
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0250 - val_loss: 0.0379
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0226 - val_loss: 0.0379
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0244 - val_loss: 0.0378
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0243 - val_loss: 0.0377
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0253 - val_loss: 0.0378
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0224 - val_loss: 0.0379
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0237 - val_loss: 0.0379
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0226 - val_loss: 0.0379
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0243 - val_loss: 0.0377
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0228 - val_loss: 0.0376
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0232 - val_loss: 0.0377
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0241 - val_loss: 0.0377
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0244 - val_loss: 0.0377
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0222 - val_loss: 0.0377
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0227 - val_loss: 0.0376
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0217 - val_loss: 0.0375
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0224 - val_loss: 0.0375
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0236 - val_loss: 0.0373
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0237 - val_loss: 0.0373
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0221 - val_loss: 0.0374
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0226 - val_loss: 0.0375
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0227 - val_loss: 0.0376
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0215 - val_loss: 0.0377
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0222 - val_loss: 0.0378
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0240 - val_loss: 0.0378
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0219 - val_loss: 0.0378
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0213 - val_loss: 0.0377
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0219 - val_loss: 0.0376
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0214 - val_loss: 0.0376
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0225 - val_loss: 0.0378
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0221 - val_loss: 0.0378
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0213 - val_loss: 0.0378
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0217 - val_loss: 0.0378
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0204 - val_loss: 0.0378
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0222 - val_loss: 0.0377
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0213 - val_loss: 0.0376
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0204 - val_loss: 0.0377
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0227 - val_loss: 0.0377
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0217 - val_loss: 0.0378
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0210 - val_loss: 0.0378
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0213 - val_loss: 0.0378
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0219 - val_loss: 0.0378
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0202 - val_loss: 0.0378
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0213 - val_loss: 0.0379
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - val_loss: 0.0379
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0212 - val_loss: 0.0378
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0218 - val_loss: 0.0378
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Features of the first three samples:
#  [[ 0.01661617  0.05085298  0.05099156  0.07429728  0.04077832  0.04678655
#    0.05454752  0.02714971  0.0799582   0.01934941  0.03510447  0.00841406
#    0.02944865  0.00914877  0.00905066  0.06348492  0.0557451   0.03591345
#    0.07096242  0.02457406  0.00845901 -0.0006645  -0.00613789 -0.00111591
#    0.08054394  0.1388445   0.02907055  0.01235102  0.02663694  0.0150983
#    0.05089332 -0.002847    0.05536893  0.04424717  0.00406431  0.10026663
#   -0.00102901  0.00048687]
#  [ 0.01465879  0.05713445  0.05973689  0.09257519  0.04581724  0.04138449
#    0.05047508  0.03170167  0.07024278  0.028987    0.04417051  0.02747973
#    0.03078136  0.01490137  0.00580386  0.05879802  0.06171421  0.03443991
#    0.0663616   0.04573836  0.02162812  0.00868331  0.00077473  0.01768805
#    0.08284452  0.14756145  0.02896822  0.0174815   0.04679687  0.02484307
#    0.05444564  0.00421096  0.06464764  0.06159373  0.00031259  0.11134869
#    0.01318384  0.0036077 ]
#  [ 0.0406495   0.05517474  0.0509115   0.10116774  0.03683096  0.06406873
#    0.07819086  0.0628246   0.10995617  0.03048003  0.05598148  0.03056233
#    0.05138395  0.00663033 -0.0080021   0.09372196  0.13803798  0.04043854
#    0.11110613  0.05402606  0.06082503  0.02740241 -0.01885646 -0.0103428
#    0.10898656  0.19988172  0.03300219  0.02648712  0.00297017  0.00806424
#    0.06841283  0.06937939  0.06302135  0.07404705 -0.00858511  0.16987821
#   -0.02534455  0.00422795]]
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_10 (Conv1D)              │ (None, 36, 128)        │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_10 (MaxPooling1D) │ (None, 18, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 18, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 16, 128)        │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_11 (MaxPooling1D) │ (None, 8, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 100)            │       102,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 38)             │         3,838 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 156,130 (609.88 KB)
#  Trainable params: 156,130 (609.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0461 - root_mean_squared_error: 0.2147 - val_loss: 0.0466 - val_root_mean_squared_error: 0.2159
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0337 - root_mean_squared_error: 0.1836 - val_loss: 0.0425 - val_root_mean_squared_error: 0.2062
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0305 - root_mean_squared_error: 0.1745 - val_loss: 0.0426 - val_root_mean_squared_error: 0.2063
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0313 - root_mean_squared_error: 0.1769 - val_loss: 0.0446 - val_root_mean_squared_error: 0.2113
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0314 - root_mean_squared_error: 0.1771 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2092
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0316 - root_mean_squared_error: 0.1778 - val_loss: 0.0424 - val_root_mean_squared_error: 0.2060
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0319 - root_mean_squared_error: 0.1786 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2026
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0285 - root_mean_squared_error: 0.1688 - val_loss: 0.0400 - val_root_mean_squared_error: 0.2001
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0304 - root_mean_squared_error: 0.1744 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1986
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0296 - root_mean_squared_error: 0.1719 - val_loss: 0.0385 - val_root_mean_squared_error: 0.1962
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0288 - root_mean_squared_error: 0.1698 - val_loss: 0.0383 - val_root_mean_squared_error: 0.1957
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0281 - root_mean_squared_error: 0.1676 - val_loss: 0.0384 - val_root_mean_squared_error: 0.1959
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0298 - root_mean_squared_error: 0.1725 - val_loss: 0.0386 - val_root_mean_squared_error: 0.1966
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0298 - root_mean_squared_error: 0.1726 - val_loss: 0.0403 - val_root_mean_squared_error: 0.2007
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0278 - root_mean_squared_error: 0.1666 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2011
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0274 - root_mean_squared_error: 0.1656 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2030
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0296 - root_mean_squared_error: 0.1720 - val_loss: 0.0399 - val_root_mean_squared_error: 0.1998
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0282 - root_mean_squared_error: 0.1680 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1975
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0283 - root_mean_squared_error: 0.1683 - val_loss: 0.0393 - val_root_mean_squared_error: 0.1982
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0276 - root_mean_squared_error: 0.1659 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1986
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0283 - root_mean_squared_error: 0.1682 - val_loss: 0.0388 - val_root_mean_squared_error: 0.1970
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0269 - root_mean_squared_error: 0.1641 - val_loss: 0.0381 - val_root_mean_squared_error: 0.1953
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0261 - root_mean_squared_error: 0.1616 - val_loss: 0.0376 - val_root_mean_squared_error: 0.1939
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0283 - root_mean_squared_error: 0.1683 - val_loss: 0.0375 - val_root_mean_squared_error: 0.1938
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0274 - root_mean_squared_error: 0.1654 - val_loss: 0.0377 - val_root_mean_squared_error: 0.1941
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0264 - root_mean_squared_error: 0.1626 - val_loss: 0.0376 - val_root_mean_squared_error: 0.1940
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0258 - root_mean_squared_error: 0.1607 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1921
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0267 - root_mean_squared_error: 0.1633 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1909
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0266 - root_mean_squared_error: 0.1630 - val_loss: 0.0374 - val_root_mean_squared_error: 0.1933
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0258 - root_mean_squared_error: 0.1605 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1922
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0263 - root_mean_squared_error: 0.1621 - val_loss: 0.0370 - val_root_mean_squared_error: 0.1925
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0270 - root_mean_squared_error: 0.1643 - val_loss: 0.0374 - val_root_mean_squared_error: 0.1934
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0253 - root_mean_squared_error: 0.1590 - val_loss: 0.0373 - val_root_mean_squared_error: 0.1932
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0259 - root_mean_squared_error: 0.1609 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1911
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0254 - root_mean_squared_error: 0.1594 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1918
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0248 - root_mean_squared_error: 0.1575 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1897
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0255 - root_mean_squared_error: 0.1596 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1886
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0261 - root_mean_squared_error: 0.1616 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1902
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0248 - root_mean_squared_error: 0.1576 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1905
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0255 - root_mean_squared_error: 0.1595 - val_loss: 0.0367 - val_root_mean_squared_error: 0.1915
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0261 - root_mean_squared_error: 0.1616 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1910
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0262 - root_mean_squared_error: 0.1619 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1886
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0267 - root_mean_squared_error: 0.1635 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1853
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0258 - root_mean_squared_error: 0.1605 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1840
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0249 - root_mean_squared_error: 0.1579 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1871
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0258 - root_mean_squared_error: 0.1605 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1906
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0237 - root_mean_squared_error: 0.1538 - val_loss: 0.0370 - val_root_mean_squared_error: 0.1922
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0252 - root_mean_squared_error: 0.1586 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1876
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0235 - root_mean_squared_error: 0.1534 - val_loss: 0.0349 - val_root_mean_squared_error: 0.1867
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0250 - root_mean_squared_error: 0.1581 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1885
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0244 - root_mean_squared_error: 0.1560 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1885
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0237 - root_mean_squared_error: 0.1540 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1883
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0229 - root_mean_squared_error: 0.1513 - val_loss: 0.0353 - val_root_mean_squared_error: 0.1879
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0249 - root_mean_squared_error: 0.1577 - val_loss: 0.0349 - val_root_mean_squared_error: 0.1867
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0235 - root_mean_squared_error: 0.1531 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1883
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0242 - root_mean_squared_error: 0.1555 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1895
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0240 - root_mean_squared_error: 0.1549 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1872
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0230 - root_mean_squared_error: 0.1517 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1854
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0238 - root_mean_squared_error: 0.1543 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1854
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0230 - root_mean_squared_error: 0.1516 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1858
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0226 - root_mean_squared_error: 0.1502 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1858
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - root_mean_squared_error: 0.1546 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1857
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0235 - root_mean_squared_error: 0.1533 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1856
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0220 - root_mean_squared_error: 0.1480 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1891
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1910
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1902
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0232 - root_mean_squared_error: 0.1522 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1886
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0235 - root_mean_squared_error: 0.1534 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1883
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0234 - root_mean_squared_error: 0.1528 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1873
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0234 - root_mean_squared_error: 0.1531 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1852
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0222 - root_mean_squared_error: 0.1487 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1859
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0230 - root_mean_squared_error: 0.1518 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1864
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0221 - root_mean_squared_error: 0.1487 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1840
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0209 - root_mean_squared_error: 0.1445 - val_loss: 0.0335 - val_root_mean_squared_error: 0.1831
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0221 - root_mean_squared_error: 0.1488 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1836
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0221 - root_mean_squared_error: 0.1488 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1840
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0235 - root_mean_squared_error: 0.1532 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1852
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0220 - root_mean_squared_error: 0.1483 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1858
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0218 - root_mean_squared_error: 0.1477 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1855
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0223 - root_mean_squared_error: 0.1494 - val_loss: 0.0347 - val_root_mean_squared_error: 0.1863
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0214 - root_mean_squared_error: 0.1461 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1854
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1884
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0240 - root_mean_squared_error: 0.1550 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1876
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0222 - root_mean_squared_error: 0.1489 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1897
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0232 - root_mean_squared_error: 0.1524 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1871
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - root_mean_squared_error: 0.1466 - val_loss: 0.0347 - val_root_mean_squared_error: 0.1862
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0220 - root_mean_squared_error: 0.1482 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1848
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0223 - root_mean_squared_error: 0.1493 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1855
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0213 - root_mean_squared_error: 0.1460 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1886
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0216 - root_mean_squared_error: 0.1471 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1884
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0223 - root_mean_squared_error: 0.1494 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1881
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0226 - root_mean_squared_error: 0.1502 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1891
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0213 - root_mean_squared_error: 0.1461 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1849
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0206 - root_mean_squared_error: 0.1434 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1840
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0222 - root_mean_squared_error: 0.1490 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1857
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0223 - root_mean_squared_error: 0.1493 - val_loss: 0.0349 - val_root_mean_squared_error: 0.1867
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0219 - root_mean_squared_error: 0.1481 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1892
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0198 - root_mean_squared_error: 0.1407 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1881
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0205 - root_mean_squared_error: 0.1431 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1872
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0221 - root_mean_squared_error: 0.1486 - val_loss: 0.0347 - val_root_mean_squared_error: 0.1861
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Root Mean Squared Error (RMSE):
# [0.2100943624973297, 0.18809355795383453, 0.17917145788669586, 0.1796686053276062, 0.17949283123016357, 0.17666301131248474, 0.1751324087381363, 0.17109933495521545, 0.17352578043937683, 0.17143592238426208, 0.17154735326766968, 0.17156922817230225, 0.1700170934200287, 0.1692579835653305, 0.168842613697052, 0.16917410492897034, 0.16961368918418884, 0.16757416725158691, 0.16769477725028992, 0.16697393357753754, 0.1650201678276062, 0.16421356797218323, 0.16292858123779297, 0.1659199595451355, 0.16306813061237335, 0.1632602959871292, 0.16283276677131653, 0.16233167052268982, 0.16149014234542847, 0.1626342087984085, 0.16179026663303375, 0.16164955496788025, 0.16148298978805542, 0.16159404814243317, 0.1599838137626648, 0.16073152422904968, 0.16067704558372498, 0.1601266711950302, 0.15969789028167725, 0.1586729884147644, 0.1591891348361969, 0.16242632269859314, 0.16144342720508575, 0.16078415513038635, 0.1582307070493698, 0.15821589529514313, 0.15774503350257874, 0.15895205736160278, 0.15557150542736053, 0.1567012518644333, 0.15618357062339783, 0.15511050820350647, 0.15580464899539948, 0.15556196868419647, 0.1557552069425583, 0.15487053990364075, 0.1556830257177353, 0.15458114445209503, 0.15327979624271393, 0.15401126444339752, 0.15197619795799255, 0.1526884138584137, 0.15106403827667236, 0.1526544690132141, 0.1532987803220749, 0.15278275310993195, 0.15300491452217102, 0.1519359052181244, 0.15290005505084991, 0.15161672234535217, 0.15316934883594513, 0.1500445455312729, 0.1504201740026474, 0.14981722831726074, 0.15043379366397858, 0.15073569118976593, 0.14876526594161987, 0.14879730343818665, 0.14947663247585297, 0.14852772653102875, 0.14875490963459015, 0.14906558394432068, 0.15391360223293304, 0.15227758884429932, 0.15214121341705322, 0.14886337518692017, 0.14826039969921112, 0.14815814793109894, 0.14708878099918365, 0.14700020849704742, 0.1485830396413803, 0.14976170659065247, 0.14725840091705322, 0.14575189352035522, 0.14849086105823517, 0.15078195929527283, 0.14690035581588745, 0.14541572332382202, 0.1461501121520996, 0.1448836773633957]
# RMSE on original scale: 32.6453441874457
