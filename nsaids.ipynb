# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, Flatten, Input, Dropout
from keras.optimizers import Adam
from keras.metrics import RootMeanSquaredError
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt  # Import sqrt function

# Load the data
df = pd.read_csv('nsaids.csv')

# Convert 'Sold_date' to datetime format and set as index
df['Sold_date'] = pd.to_datetime(df['Sold_date'], format='%m/%d/%y')
df.set_index('Sold_date', inplace=True)

# Aggregate sales data on a weekly basis for each product
weekly_data = df.pivot_table(values='Sold_quantity', index='Sold_date', 
                             columns='Product_details', aggfunc='sum').resample('W').sum()

# Normalize the sales data
scaler = MinMaxScaler()
weekly_data_scaled = scaler.fit_transform(weekly_data)
weekly_data_scaled = pd.DataFrame(weekly_data_scaled, index=weekly_data.index, columns=weekly_data.columns)

# Prepare data for LSTM
def create_sequences(data, sequence_length):
    x = []
    y = []
    for i in range(len(data) - sequence_length):
        x.append(data.iloc[i:i + sequence_length].values)
        y.append(data.iloc[i + sequence_length].values)
    return np.array(x), np.array(y)

sequence_length = 2  # Number of weeks used to predict the next week
x_lstm, y_lstm = create_sequences(weekly_data_scaled, sequence_length)

print("x_lstm shape:", x_lstm.shape)
print("y_lstm shape:", y_lstm.shape)
# Out:
# x_lstm shape: (162, 2, 60)
# y_lstm shape: (162, 60)

# %%
# Define the LSTM model to extract features
lstm_model = Sequential([
    Input(shape=(sequence_length, len(weekly_data_scaled.columns))),
    LSTM(60, activation='tanh', recurrent_activation='sigmoid', return_sequences=False),
])

# Compile the LSTM model
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Fit the LSTM model
history = lstm_model.fit(x_lstm, y_lstm, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# Extract features using LSTM
features = lstm_model.predict(x_lstm)

# Print the features of the first three samples to see what they look like
print("Features of the first three samples:\n", features[:3])

# Enhanced CNN model with additional complexity and dropout for regularization
input_shape = (features.shape[1], features.shape[2]) if len(features.shape) == 3 else (features.shape[1], 1)
cnn_model_enhanced = Sequential([
    Input(shape=input_shape),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Dropout(0.2),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.2),
    Dense(len(weekly_data.columns))
])

cnn_model_enhanced.compile(optimizer=Adam(), loss='mean_squared_error', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Model summary
cnn_model_enhanced.summary()

# Fit the CNN model
history = cnn_model_enhanced.fit(features, y_lstm, epochs=100, batch_size=32, validation_split=0.2)

# Predictions made by the CNN model
scaled_predictions = cnn_model_enhanced.predict(features)

# Display RMSE
print("Root Mean Squared Error (RMSE):")
print(history.history['root_mean_squared_error'])

# Assuming `y_lstm` and `scaled_predictions` have the same second dimension (number of features or products)
if scaled_predictions.shape[1] == y_lstm.shape[1]:
    actual_predictions = scaler.inverse_transform(scaled_predictions)
    actual_targets = scaler.inverse_transform(y_lstm)
else:
    print("Error: Mismatch in dimensions between predictions and actuals.")

# Calculate RMSE in original units
rmse_original = sqrt(mean_squared_error(actual_targets, actual_predictions))
print("RMSE on original scale:", rmse_original)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0512 - val_loss: 0.0550
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0478 - val_loss: 0.0519
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0444 - val_loss: 0.0494
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0422 - val_loss: 0.0472
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0386 - val_loss: 0.0453
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0374 - val_loss: 0.0437
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0353 - val_loss: 0.0424
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0341 - val_loss: 0.0414
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0326 - val_loss: 0.0406
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0315 - val_loss: 0.0399
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0313 - val_loss: 0.0393
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0294 - val_loss: 0.0389
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0294 - val_loss: 0.0385
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0281 - val_loss: 0.0382
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0279 - val_loss: 0.0380
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0269 - val_loss: 0.0376
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0254 - val_loss: 0.0373
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0259 - val_loss: 0.0371
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0250 - val_loss: 0.0369
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0257 - val_loss: 0.0367
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0247 - val_loss: 0.0366
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0240 - val_loss: 0.0365
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0236 - val_loss: 0.0363
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0239 - val_loss: 0.0362
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0232 - val_loss: 0.0361
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0247 - val_loss: 0.0362
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0241 - val_loss: 0.0362
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0237 - val_loss: 0.0362
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0232 - val_loss: 0.0363
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0233 - val_loss: 0.0364
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0225 - val_loss: 0.0365
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0225 - val_loss: 0.0365
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0221 - val_loss: 0.0365
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0230 - val_loss: 0.
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0282 - root_mean_squared_error: 0.1679 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1905
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0279 - root_mean_squared_error: 0.1672 - val_loss: 0.0371 - val_root_mean_squared_error: 0.1925
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0279 - root_mean_squared_error: 0.1671 - val_loss: 0.0370 - val_root_mean_squared_error: 0.1924
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0272 - root_mean_squared_error: 0.1648 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1913
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0274 - root_mean_squared_error: 0.1656 - val_loss: 0.0367 - val_root_mean_squared_error: 0.1914
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0278 - root_mean_squared_error: 0.1667 - val_loss: 0.0371 - val_root_mean_squared_error: 0.1925
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0264 - root_mean_squared_error: 0.1625 - val_loss: 0.0367 - val_root_mean_squared_error: 0.1916
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0265 - root_mean_squared_error: 0.1629 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1912
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0260 - root_mean_squared_error: 0.1613 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1904
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0262 - root_mean_squared_error: 0.1620 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1913
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0273 - root_mean_squared_error: 0.1650 - val_loss: 0.0370 - val_root_mean_squared_error: 0.1923
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0260 - root_mean_squared_error: 0.1613 - val_loss: 0.0367 - val_root_mean_squared_error: 0.1917
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0257 - root_mean_squared_error: 0.1602 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1920
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0252 - root_mean_squared_error: 0.1587 - val_loss: 0.0375 - val_root_mean_squared_error: 0.1937
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0253 - root_mean_squared_error: 0.1589 - val_loss: 0.0378 - val_root_mean_squared_error: 0.1944
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0252 - root_mean_squared_error: 0.1588 - val_loss: 0.0373 - val_root_mean_squared_error: 0.1932
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0248 - root_mean_squared_error: 0.1576 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1912
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0244 - root_mean_squared_error: 0.1561 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1919
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0259 - root_mean_squared_error: 0.1608 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1909
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0246 - root_mean_squared_error: 0.1568 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1907
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0242 - root_mean_squared_error: 0.1557 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1902
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0242 - root_mean_squared_error: 0.1555 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1894
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0243 - root_mean_squared_error: 0.1559 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1895
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0250 - root_mean_squared_error: 0.1580 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1914
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0247 - root_mean_squared_error: 0.1573 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1919
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0244 - root_mean_squared_error: 0.1561 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1908
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233 - root_mean_squared_error: 0.1527 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1899
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0238 - root_mean_squared_error: 0.1543 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1894
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0237 - root_mean_squared_error: 0.1539 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1908
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0240 - root_mean_squared_error: 0.1550 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1919
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0229 - root_mean_squared_error: 0.1515 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1904
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0236 - root_mean_squared_error: 0.1536 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1904
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0242 - root_mean_squared_error: 0.1554 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1919
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233 - root_mean_squared_error: 0.1525 - val_loss: 0.0376 - val_root_mean_squared_error: 0.1939
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0229 - root_mean_squared_error: 0.1512 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1920
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0234 - root_mean_squared_error: 0.1531 - val_loss: 0.0361 - val_root_mean_squared_error: 0.1901
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0226 - root_mean_squared_error: 0.1505 - val_loss: 0.0357 - val_root_mean_squared_error: 0.1888
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0228 - root_mean_squared_error: 0.1510 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1896
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0224 - root_mean_squared_error: 0.1496 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1910
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0226 - root_mean_squared_error: 0.1503 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1906
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0229 - root_mean_squared_error: 0.1514 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1903
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0225 - root_mean_squared_error: 0.1499 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1913
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0235 - root_mean_squared_error: 0.1533 - val_loss: 0.0361 - val_root_mean_squared_error: 0.1900
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0224 - root_mean_squared_error: 0.1497 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1913
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233 - root_mean_squared_error: 0.1525 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1909
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1904
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0223 - root_mean_squared_error: 0.1493 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1913
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0222 - root_mean_squared_error: 0.1488 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1918
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0219 - root_mean_squared_error: 0.1480 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1918
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0224 - root_mean_squared_error: 0.1496 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1912
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0225 - root_mean_squared_error: 0.1501 - val_loss: 0.0361 - val_root_mean_squared_error: 0.1899
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0220 - root_mean_squared_error: 0.1484 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1894
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0229 - root_mean_squared_error: 0.1512 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1896
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0221 - root_mean_squared_error: 0.1486 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1903
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - root_mean_squared_error: 0.1466 - val_loss: 0.0374 - val_root_mean_squared_error: 0.1934
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0224 - root_mean_squared_error: 0.1497 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1897
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0227 - root_mean_squared_error: 0.1507 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1896
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0216 - root_mean_squared_error: 0.1469 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1909
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0218 - root_mean_squared_error: 0.1478 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1893
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0220 - root_mean_squared_error: 0.1484 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1902
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0216 - root_mean_squared_error: 0.1469 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1909
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.