# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, Flatten, Input, Dropout
from keras.optimizers import Adam
from keras.metrics import RootMeanSquaredError
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt  # Import sqrt function

# Load the data
df = pd.read_csv('antiasthma.csv')

# Convert 'Sold_date' to datetime format and set as index
df['Sold_date'] = pd.to_datetime(df['Sold_date'], format='%m/%d/%y')
df.set_index('Sold_date', inplace=True)

# Aggregate sales data on a weekly basis for each product
weekly_data = df.pivot_table(values='Sold_quantity', index='Sold_date', 
                             columns='Product_details', aggfunc='sum').resample('W').sum()

# Normalize the sales data
scaler = MinMaxScaler()
weekly_data_scaled = scaler.fit_transform(weekly_data)
weekly_data_scaled = pd.DataFrame(weekly_data_scaled, index=weekly_data.index, columns=weekly_data.columns)

# Prepare data for LSTM
def create_sequences(data, sequence_length):
    x = []
    y = []
    for i in range(len(data) - sequence_length):
        x.append(data.iloc[i:i + sequence_length].values)
        y.append(data.iloc[i + sequence_length].values)
    return np.array(x), np.array(y)

sequence_length = 2  # Number of weeks used to predict the next week
x_lstm, y_lstm = create_sequences(weekly_data_scaled, sequence_length)

print("x_lstm shape:", x_lstm.shape)
print("y_lstm shape:", y_lstm.shape)
# Out:
# x_lstm shape: (161, 2, 45)
# y_lstm shape: (161, 45)

# %%
lstm_model = Sequential([
    Input(shape=(sequence_length, len(weekly_data_scaled.columns))),
    LSTM(45, activation='tanh', recurrent_activation='sigmoid', return_sequences=False),
])
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Fit the LSTM model
history = lstm_model.fit(x_lstm, y_lstm, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# Extract features using LSTM
features = lstm_model.predict(x_lstm)

# Define and compile the CNN model
input_shape = (features.shape[1], 1)
cnn_model_enhanced = Sequential([
    Input(shape=input_shape),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Dropout(0.2),
    Conv1D(128, 3, activation='relu'),
    MaxPooling1D(2),
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.2),
    Dense(len(weekly_data.columns))
])
cnn_model_enhanced.compile(optimizer=Adam(), loss='mean_squared_error', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Fit the CNN model
history_cnn = cnn_model_enhanced.fit(features, y_lstm, epochs=100, batch_size=32, validation_split=0.2)

# Predictions made by the CNN model
scaled_predictions = cnn_model_enhanced.predict(features)

# Inverse transform the scaled predictions to original scale
actual_predictions = scaler.inverse_transform(scaled_predictions)

# Create a DataFrame for the forecasted data
forecast_df = pd.DataFrame(actual_predictions, index=weekly_data.index[sequence_length:], columns=weekly_data.columns)

# Reindex the forecast DataFrame to ensure it includes the required date range
forecast_df = forecast_df.reindex(pd.date_range(start=weekly_data.index[sequence_length], end=weekly_data.index[-1], freq='W'))

# Display the forecast for the week of February 5 to 11, 2024
forecast_week = forecast_df.loc['2024-02-04']  # The week starting on February 4, 2024
sorted_forecast_week = forecast_week.sort_values(ascending=False)  # Sort values from highest to lowest

# Convert to DataFrame and save the sorted forecast to Excel
sorted_forecast_week_df = sorted_forecast_week.to_frame(name='Sold_quantity')
sorted_forecast_week_df.index.name = 'Product_details'
sorted_forecast_week_df.reset_index(inplace=True)
sorted_forecast_week_df.to_excel('antiasthma_sorted_by_quantity.xlsx', index=False)

# Display RMSE
print("Root Mean Squared Error (RMSE):", history_cnn.history['root_mean_squared_error'])

# Calculate and print RMSE in original units
rmse_original = sqrt(mean_squared_error(y_lstm, actual_predictions))
print("RMSE on original scale:", rmse_original)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0391 - val_loss: 0.0558
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0405 - val_loss: 0.0538
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0382 - val_loss: 0.0521
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0348 - val_loss: 0.0505
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0364 - val_loss: 0.0491
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0358 - val_loss: 0.0478
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0346 - val_loss: 0.0466
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0323 - val_loss: 0.0455
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0326 - val_loss: 0.0445
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0314 - val_loss: 0.0436
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0300 - val_loss: 0.0428
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0305 - val_loss: 0.0421
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0280 - val_loss: 0.0414
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0273 - val_loss: 0.0409
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0268 - val_loss: 0.0404
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0270 - val_loss: 0.0401
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0278 - val_loss: 0.0398
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0265 
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0193 - root_mean_squared_error: 0.1389 - val_loss: 0.0396 - val_root_mean_squared_error: 0.1989
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0197 - root_mean_squared_error: 0.1403 - val_loss: 0.0396 - val_root_mean_squared_error: 0.1991
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0199 - root_mean_squared_error: 0.1412 - val_loss: 0.0399 - val_root_mean_squared_error: 0.1997
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0183 - root_mean_squared_error: 0.1350 - val_loss: 0.0401 - val_root_mean_squared_error: 0.2003
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0198 - root_mean_squared_error: 0.1407 - val_loss: 0.0400 - val_root_mean_squared_error: 0.2001
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0195 - root_mean_squared_error: 0.1395 - val_loss: 0.0393 - val_root_mean_squared_error: 0.1982
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0192 - root_mean_squared_error: 0.1385 - val_loss: 0.0399 - val_root_mean_squared_error: 0.1998
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0186 - root_mean_squared_error: 0.1364 - val_loss: 0.0397 - val_root_mean_squared_error: 0.1993
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0191 - root_mean_squared_error: 0.1380 - val_loss: 0.0399 - val_root_mean_squared_error: 0.1999
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319 - val_loss: 0.0400 - val_root_mean_squared_error: 0.1999
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0398 - val_root_mean_squared_error: 0.1995
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0189 - root_mean_squared_error: 0.1372 - val_loss: 0.0399 - val_root_mean_squared_error: 0.1996
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0181 - root_mean_squared_error: 0.1346 - val_loss: 0.0402 - val_root_mean_squared_error: 0.2004
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0173 - root_mean_squared_error: 0.1315 - val_loss: 0.0400 - val_root_mean_squared_error: 0.2000
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0166 - root_mean_squared_error: 0.1290 - val_loss: 0.0401 - val_root_mean_squared_error: 0.2003
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0178 - root_mean_squared_error: 0.1334 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - root_mean_squared_error: 0.1305 - val_loss: 0.0403 - val_root_mean_squared_error: 0.2009
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0172 - root_mean_squared_error: 0.1311 - val_loss: 0.0402 - val_root_mean_squared_error: 0.2006
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - root_mean_squared_error: 0.1304 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2016
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0158 - root_mean_squared_error: 0.1254 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2020
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0168 - root_mean_squared_error: 0.1295 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0166 - root_mean_squared_error: 0.1288 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2014
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0158 - root_mean_squared_error: 0.1258 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2018
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0168 - root_mean_squared_error: 0.1298 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2018
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0162 - root_mean_squared_error: 0.1272 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2020
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0162 - root_mean_squared_error: 0.1271 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2026
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0158 - root_mean_squared_error: 0.1257 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2021
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0154 - root_mean_squared_error: 0.1242 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2021
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0156 - root_mean_squared_error: 0.1247 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2026
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2032
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0150 - root_mean_squared_error: 0.1224 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2024
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0156 - root_mean_squared_error: 0.1247 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2026
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0148 - root_mean_squared_error: 0.1216 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2028
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2030
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0148 - root_mean_squared_error: 0.1217 - val_loss: 0.0416 - val_root_mean_squared_error: 0.2040
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2031
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0150 - root_mean_squared_error: 0.1223 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2026
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0416 - val_root_mean_squared_error: 0.2038
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2030
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2035
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0140 - root_mean_squared_error: 0.1181 - val_loss: 0.0419 - val_root_mean_squared_error: 0.2047
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2033
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0136 - root_mean_squared_error: 0.1168 - val_loss: 0.0416 - val_root_mean_squared_error: 0.2039
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171 - val_loss: 0.0418 - val_root_mean_squared_error: 0.2044
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189 - val_loss: 0.0418 - val_root_mean_squared_error: 0.2046
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2037
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149 - val_loss: 0.0418 - val_root_mean_squared_error: 0.2045
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0419 - val_root_mean_squared_error: 0.2048
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162 - val_loss: 0.0419 - val_root_mean_squared_error: 0.2047
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - root_mean_squared_error: 0.1163 - val_loss: 0.0417 - val_root_mean_squared_error: 0.2042
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - root_mean_squared_error: 0.1144 - val_loss: 0.0425 - val_root_mean_squared_error: 0.2061
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180 - val_loss: 0.0421 - val_root_mean_squared_error: 0.2053
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0424 - val_root_mean_squared_error: 0.2058
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0420 - val_root_mean_squared_error: 0.2049
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0129 - root_mean_squared_error: 0.1138 - val_loss: 0.0425 - val_root_mean_squared_error: 0.2062
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0422 - val_root_mean_squared_error: 0.2055
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0421 - val_root_mean_squared_error: 0.2052
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0424 - val_root_mean_squared_error: 0.2060
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153 - val_loss: 0.0432 - val_root_mean_squared_error: 0.2078
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140 - val_loss: 0.0423 - val_root_mean_squared_error: 0.2057
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.0421 - val_root_mean_squared_error: 0.2051
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0128 